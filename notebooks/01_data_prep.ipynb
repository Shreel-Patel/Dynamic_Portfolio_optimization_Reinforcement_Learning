# %% [markdown]
# # 01 — Data prep
#
# Calls the same pipeline as the CLI:
#
# ```bash
# python data/fetch.py
# python data/preprocess.py
# ```
#
# Outputs: `data/raw/adj_close.csv`, `data/processed/features_returns.csv`.
