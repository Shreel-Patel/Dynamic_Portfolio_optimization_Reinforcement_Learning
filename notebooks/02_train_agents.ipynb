# %% [markdown]
# # 02 — Train agents
#
# ```bash
# python agents/train.py
# tensorboard --logdir ../results/logs
# ```
#
# Optional quick run: `python agents/train.py --timesteps 100000 --agents SAC`
